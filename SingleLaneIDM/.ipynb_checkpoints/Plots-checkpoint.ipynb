# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import copy

# %% [markdown]
# # All dataset  files location goes here

# %%
dataset_locs = {
    'only local view': "/home/mayank/Videos/single-ring-road-with-light/SingleLaneIDM/LocalView10m/Results/dataset.pkl",
    "full access comm": "/home/mayank/Videos/single-ring-road-with-light/SingleLaneIDM/LocalView10Comm10/Results/dataset.pkl",
    "restriced access comm": "/home/mayank/Videos/single-ring-road-with-light/SingleLaneIDM/LocalView10Comm10_regs_4/Results/dataset.pkl"
}

print(dataset_locs)
# Out:
# {'only local view': '/home/mayank/Videos/single-ring-road-with-light/SingleLaneIDM/LocalView10m/Results/dataset.pkl', 'full access comm': '/home/mayank/Videos/single-ring-road-with-light/SingleLaneIDM/LocalView10Comm10/Results/dataset.pkl', 'restriced access comm': '/home/mayank/Videos/single-ring-road-with-light/SingleLaneIDM/LocalView10Comm10_regs_4/Results/dataset.pkl'}

# %% [markdown]
# # Read all Dataset

# %%
def readPKL(fname):
    
    with open(fname, "rb") as handle:
        data_dict = pickle.load(handle)
    
    return copy.deepcopy(data_dict)

# %%
data_dict = {}
for case in dataset_locs.keys():
    data_dict[case] = readPKL(dataset_locs[case])

# %% [markdown]
# # Plot Agent Avg Speed

# %%
agent_vel = {}

for case in dataset_locs.keys():
    
    global_vel_data = {}
    
    for density in data_dict[case]["data"].keys():
        vel_data = []
        
        for episode_num in data_dict[case]["data"][density].keys():
            episode_data = []
            
            for step in range(0, len(data_dict[case]["data"][density][episode_num]["agent_vel"])):
                episode_data.append(data_dict[case]["data"][density][episode_num]["agent_vel"][step])
            
            vel_data.append(episode_data)
        
        global_vel_data[density] = copy.deepcopy(vel_data)
    
    agent_vel[case] = global_vel_data

# %%
# Length of episodes

# %%
avg_speeds_case = {}

for case in agent_vel.keys():
    
    avg_speeds = []
    
    for density in agent_vel[case].keys():
        for episode in agent_vel[case][density]:
# Out:
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 2052
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 3030
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 591
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 3573
# only local view 573
# only local view 5500
# only local view 5500
# only local view 3342
# only local view 5500
# only local view 4541
# only local view 5500
# only local view 3602
# only local view 5500
# only local view 1364
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 2518
# only local view 5500
# only local view 5500
# only local view 2988
# only local view 2551
# only local view 5500
# only local view 2945
# only local view 5500
# only local view 2497
# only local view 2500
# only local view 2072
# only local view 5500
# only local view 431
# only local view 1218
# only local view 5500
# only local view 5500
# only local view 5500
# only local view 1263
# only local view 909
# only local view 5036
# only local view 5500
# only local view 5500
# only local view 2601
# only local view 1206
# only local view 4462
# only local view 1193
# only local view 1339
# only local view 4426
# only local view 4428
# only local view 5500
# only local view 5500
# only local view 4428
# only local view 3053
# only local view 2613
# only local view 1280
# only local view 3233
# only local view 5500
# only local view 5500
# only local view 831
# only local view 2783
# only local view 302
# only local view 1282
# only local view 5500
# only local view 1277
# only local view 1296
# only local view 3697
# only local view 1277
# only local view 1271
# only local view 3271
# only local view 3677
# only local view 5500
# only local view 1818
# only local view 5500
# only local view 5251
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 3165
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 1462
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 1533
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 5500
# full access comm 2055
# full access comm 5500
# full access comm 5500
# full access comm 5500
# restriced access comm 462
# restriced access comm 5500
# restriced access comm 463
# restriced access comm 5500
# restriced access comm 2619
# restriced access comm 5500
# restriced access comm 1861
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 4529
# restriced access comm 5500
# restriced access comm 1143
# restriced access comm 448
# restriced access comm 3210
# restriced access comm 2612
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 4398
# restriced access comm 609
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 4402
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 1320
# restriced access comm 5500
# restriced access comm 3143
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 418
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 4255
# restriced access comm 4828
# restriced access comm 5500
# restriced access comm 2081
# restriced access comm 1282
# restriced access comm 4245
# restriced access comm 4826
# restriced access comm 4261
# restriced access comm 4250
# restriced access comm 2954
# restriced access comm 2083
# restriced access comm 916
# restriced access comm 3553
# restriced access comm 1782
# restriced access comm 3098
# restriced access comm 4244
# restriced access comm 2095
# restriced access comm 3131
# restriced access comm 5500
# restriced access comm 3559
# restriced access comm 910
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 1726
# restriced access comm 835
# restriced access comm 3786
# restriced access comm 1738
# restriced access comm 1960
# restriced access comm 1734
# restriced access comm 1725
# restriced access comm 5500
# restriced access comm 1736
# restriced access comm 842
# restriced access comm 5500
# restriced access comm 1723
# restriced access comm 854
# restriced access comm 1205
# restriced access comm 5500
# restriced access comm 1735
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 2554
# restriced access comm 2310
# restriced access comm 5500
# restriced access comm 4183
# restriced access comm 4675
# restriced access comm 1801
# restriced access comm 4444
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 792
# restriced access comm 5500
# restriced access comm 962
# restriced access comm 5286
# restriced access comm 3310
# restriced access comm 1489
# restriced access comm 5500
# restriced access comm 5500
# restriced access comm 800
